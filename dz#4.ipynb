# %% [markdown]
# <a href="https://colab.research.google.com/github/NavruzBekk/python/blob/main/dz%234.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# импортируем модули
import numpy as np
import matplotlib.pyplot as plt

y = lambda x: np.sin(x)
fig = plt.subplots()
x = np.linspace(0, 30,100)
plt.plot(x, y(x))

plt.show()
